# %%
#Set
a = {10,2,1,10,9,10}
type(a)
print(a)
str1 = 'haldia'
str2 = set(str1)
print(str2)
# Out:
# {1, 10, 2, 9}
# {'d', 'a', 'l', 'i', 'h'}

# %%
#dict.
a = {10:'mca1', 20:'mca2', 30:'mca3'}
print(a[30])
a[40] = 'mca4'
a['abc'] = 10
a[50] = ''
a[50] = 'kajshdfkj'
print(a.keys())
print(a.values())
type(a)
a[10] = 'mca0'
print(a)
b = {}
b[1] = 'abc'
b[2] = 'bca'
b[3] = 'mca'
print(b)
c = {10:['mca1','m'], 20:'mca2', 30:'mca3'}
print(c)
c.pop(30)
print(c)
# Out:
# mca3
# dict_keys([10, 20, 30, 40, 'abc', 50])
# dict_values(['mca1', 'mca2', 'mca3', 'mca4', 10, 'kajshdfkj'])
# {10: 'mca0', 20: 'mca2', 30: 'mca3', 40: 'mca4', 'abc': 10, 50: 'kajshdfkj'}
# {1: 'abc', 2: 'bca', 3: 'mca'}
# {10: ['mca1', 'm'], 20: 'mca2', 30: 'mca3'}
# {10: ['mca1', 'm'], 20: 'mca2'}

# %%
a = '''abc'''
b = "xyz"
c = 'mno'
print(c)
# Out:
# mno

# %%
# This is Hit's Site
a = "This is Hit's Site"
print(a)
# Out:
# This is Hit's Site

# %%
#1. Hi
#2. Hello
#3. HIT
print("1.Hi \n2.Hello \n 3.HIT")
# Out:
# 1.Hi
# 2.Hello
#  3.HIT

# %%
#Input
a = float(input("Enter a no."))
b = input()
c = input()
b = a+10
print(b)
# Out:
# Enter a no.10.33
# 20.33

# %%
# Arithmatic Operator
# + - * / // ** %
5/3
5**3
5%3
# Out:
# 2

# %%
# conditional operator
# >, >=, <, <=, ==, 
# and or not

# %%
# My first number is 2 and 2nd number is 3 and addition is 5
a = 4
b = 3
c = a+b
print('My first number is {} and 2nd number is {} and addition is {}'.format(a,b,c))
print('My first number is {1} and 2nd number is {0} and addition is {2}'.format(a,b,c))
print('My first number is {x} and 2nd number is {y} and addition is {z}'.format(x=a,y=b,z=c))
# Out:
# My first number is 4 and 2nd number is 3 and addition is 7
# My first number is 3 and 2nd number is 4 and addition is 7
# My first number is 4 and 2nd number is 3 and addition is 7
