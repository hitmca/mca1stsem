# %%
import pandas as pd
import numpy as np

# %%
"""this program will show hello world message only
jkhasgdjdasgj"""
print('hello world')
# Out:
# hello world

# %%
# Number
# Integer # Float # Complex
a = 5/10

b = 5/10
print(a+b)
print(id(a))
print(id(b))
print(id(c))
print(type(a))
a = 10.11
b = 2.33
print(type(a))
print(a+b)
print(id(a))
print(id(c))

#a+b*j
#10.35
#10+35*sqrt(-1)
# Out:
# 1.0
# 140104585405744
# 140104585406352
# 94099378498336
# <class 'float'>
# <class 'float'>
# 12.44
# 140104585408016
# 94099378498336

# %%
# Boolean 
a = 10>5
print(a)
# Out:
# True

# %%
# Series
# Array
a = 10
b = 10
a = 257
b = 257
c = (a==b)
print(c)
a = 'hit, haldia, pin-721657'
#a[0] = 'g'
b = len(a)
print(type(a))
print(b)
print(a[0:10:4]) #[staring:ending:step]
print(a[:10])
print(a[:])
print(id(a))
print(id(b))
# Out:
# True
# <class 'str'>
# 23
# h d
# hit, haldi
# hit, haldia, pin-721657
# 140104585091792
# 94099378498752

# %%
# List

a = [10, 20, 20.11, 'hit', 'iit']
a[0] = 100
print(a[0:2])
type(a)
# Out:
# [100, 20]
# list

# %%
a = '721657'
b = int(a)
a = 10
b = 20
#c = a*b
print(a*b)
type(a)
# Out:
# 200
# int

# %%
(10+20)*100
# Out:
# 3000

# %%
a = [10, 20, 20.11, 'hit', 'iit', 500]
b = [10, 20, 20.11, [1,2,[5,6,7],3],'hit', 'iit']
c = []
a.append(100)
a.append('nit')
a.insert(1, 500)
a.remove(500)
print(b[0:3])
c.append(100)
a.pop(1)
print(a)
c.insert(0,200)
print(c)
# Out:
# [10, 20, 20.11]
# [10, 20.11, 'hit', 'iit', 500, 100, 'nit']
# [200, 100]

# %%
#Tuple
a = (10, 10, 20, 20.11, 'hit', 'iit', 500)
a.count('hit')
#print(a[0])
# Out:
# 1

# %%
# Range
a = range(11,20,3)
for i in a:
  print(i)
# Out:
# 11
# 14
# 17
